# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fp = "./data/histogram.bin"

# %%
f = open(fp, "rb")

# %%
Nbins = np.fromfile(f, dtype=np.uint32, count=1)[0]

# %%
HV = np.fromfile(f, dtype=np.float64, count = Nbins)

# %%
H = np.fromfile(f, dtype=np.uint64, count = Nbins)

# %%
f.close()

# %%
plt.plot(HV, H, 'o')
